# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.26.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.26.14)

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax
import pandas as pd

# %%
df = pd.read_csv("/content/hogwarts_legacy_reviews.csv")
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df = df.head(100)

# %%
df.head()
# Out:
#    Playtime  Feedback                                             Review
# 0        16  Positive                                      Greattt Game!
# 1        26  Positive  9/10Fantastic experience. A true Wizarding Wor...
# 2        29  Positive                                           worth it
# 3        24  Positive  I've been waiting 84 YEARSSSSSSSS.The game is ...
# 4         7  Positive       very fun game (it is not transphobic at all)

# %%
example = df.iloc[80]['Review']

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
def polarity_scores_roberta(example):
  encoded_text = tokenizer(example, return_tensors='pt')
  output = model(**encoded_text)
  scores = output[0][0].detach().numpy()
  scores = softmax(scores)
  scores_dict = {
      #'id': df.index[df['Review'] == example][0],
      'roberta_neg' : scores[0],
      'roberta_neu' : scores[1],
      'roberta_pos' : scores[2],
      'Review' : example
  }
  return scores_dict

# %%
roberta_result = {}

for i, row in df.iterrows():
  try:
    text = row['Review']
    roberta_result[i] = polarity_scores_roberta(text)
  except RuntimeError:
    print(f'error at', i)
# Out:
# error at 30

# %%
roberta_result
# Out:
# {0: {'roberta_neg': 0.0026876328,
#   'roberta_neu': 0.024787739,
#   'roberta_pos': 0.9725246,
#   'Review': 'Greattt Game!'},
#  1: {'roberta_neg': 0.0027845881,
#   'roberta_neu': 0.029467132,
#   'roberta_pos': 0.96774834,
#   'Review': '9/10Fantastic experience. A true Wizarding World experience. Play it and experience it, the castle alone is the worth it. And thats only a third of the game.'},
#  2: {'roberta_neg': 0.11699291,
#   'roberta_neu': 0.573539,
#   'roberta_pos': 0.30946803,
#   'Review': 'worth it'},
#  3: {'roberta_neg': 0.008601023,
#   'roberta_neu': 0.033361707,
#   'roberta_pos': 0.95803726,
#   'Review': "I've been waiting 84 YEARSSSSSSSS.The game is everything I could have hoped for and more."},
#  4: {'roberta_neg': 0.009220093,
#   'roberta_neu': 0.06757006,
#   'roberta_pos': 0.92320985,
#   'Review': 'very fun game (it is not transphobic at all)'},
#  5: {'roberta_neg': 0.17814165,
#   'roberta_neu': 0.34829932,
#   'roberta_pos': 0.47355905,
#   'Review': 'Better than expected! But bad optimization.'},
#  6: {'roberta_neg': 0.7910365,
#   'roberta_neu': 0.17244339,
#   'roberta_pos': 0.036520217,
#   'Review': 'Garbage'},
#  7: {'roberta_neg': 0.00286732,
#   'roberta_neu': 0.07127454,
#   'roberta_pos': 0.92585814,
#   'Review': 'Full of surprises!'},
#  8: {'roberta_neg': 0.001419484,
#   'roberta_neu': 0.010037119,
#   'roberta_pos': 0.9885434,
#   'Review': 'Fun Harry Potter Game! My sister and I Enjoyed it.'},
#  9: {'roberta_neg': 0.0015756671,
#   'roberta_neu': 0.013562726,
#   'roberta_pos': 0.9848616,
#   'Review': 'One of the best games I have bought in my recent memory'},
#  10: {'roberta_neg': 0.93465716,
#   'roberta_neu': 0.061950967,
#   'roberta_pos': 0.00339183,
#   'Review': 'Denuvo Anti-Tampering makes the game stutter, same as every other game that adopts this cancer.'},
#  11: {'roberta_neg': 0.00539426,
#   'roberta_neu': 0.04893881,
#   'roberta_pos': 0.94566685,
#   'Review': 'very fun'},
#  12: {'roberta_neg': 0.013923711,
#   'roberta_neu': 0.05291336,
#   'roberta_pos': 0.93316287,
#   'Review': "I have awaited this game for a over a decade, and I wasn't disappointed. Quite an achievement."},
#  13: {'roberta_neg': 0.0019100696,
#   'roberta_neu': 0.011961594,
#   'roberta_pos': 0.98612833,
#   'Review': 'The best game of the year'},
#  14: {'roberta_neg': 0.0062232115,
#   'roberta_neu': 0.08819689,
#   'roberta_pos': 0.9055799,
#   'Review': 'Very aesthetically made game'},
#  15: {'roberta_neg': 0.0025368854,
#   'roberta_neu': 0.009181772,
#   'roberta_pos': 0.9882813,
#   'Review': "Love the game! I needed to upgrade my graphics card and more RAM, but now that I'm all set up, it's great!"},
#  16: {'roberta_neg': 0.012554671,
#   'roberta_neu': 0.106544726,
#   'roberta_pos': 0.8809006,
#   'Review': 'Excellent game'},
#  17: {'roberta_neg': 0.0021409728,
#   'roberta_neu': 0.00768715,
#   'roberta_pos': 0.99017185,
#   'Review': 'Great game. Love all the little details to make this game come alive'},
#  18: {'roberta_neg': 0.014342455,
#   'roberta_neu': 0.11094898,
#   'roberta_pos': 0.87470853,
#   'Review': 'I no watch harry potter movies but being wizard fun. Good game. Make DLC'},
#  19: {'roberta_neg': 0.8159018,
#   'roberta_neu': 0.16825283,
#   'roberta_pos': 0.015845323,
#   'Review': "7/10 - my immersion is somewhat broken by the fact that 18th century Scotland school has 90% of the professors and more than half of the students with foreign accent. How many are there in the movies? And that's 20th century"},
#  20: {'roberta_neg': 0.0011907575,
#   'roberta_neu': 0.009053503,
#   'roberta_pos': 0.9897557,
#   'Review': "After a long time I've spent so much time on a Single-Player Game. I am seriously hooked on it. I am looking forward to further content for this game."},
#  21: {'roberta_neg': 0.002670501,
#   'roberta_neu': 0.01497299,
#   'roberta_pos': 0.9823564,
#   'Review': 'it looks amazing'},
#  22: {'roberta_neg': 0.0020595475,
#   'roberta_neu': 0.012319247,
#   'roberta_pos': 0.98562115,
#   'Review': 'I love this game, despite completing the story there is tons more to do :) Secretly hoping that, at a later date, there will be further progression where you becoming a working member of the ministry with new stories/missions :)'},
#  23: {'roberta_neg': 0.011889653,
#   'roberta_neu': 0.065451846,
#   'roberta_pos': 0.9226585,
#   'Review': "The visuals in the game are stunning.  There are numerous character customization options.  I play on a PC and don't recommend using a keyboard if you have a controller."},
#  24: {'roberta_neg': 0.0032742454,
#   'roberta_neu': 0.024459742,
#   'roberta_pos': 0.972266,
#   'Review': 'awesome game 10/10'},
#  25: {'roberta_neg': 0.0040925415,
#   'roberta_neu': 0.19222786,
#   'roberta_pos': 0.80367965,
#   'Review': 'HOGWARTS + RPG = EXCELLENT'},
#  26: {'roberta_neg': 0.031365804,
#   'roberta_neu': 0.12865148,
#   'roberta_pos': 0.8399827,
#   'Review': 'there were major performance issues to start with, but they seem to have been mostly fixed. Overall a great AAA game!'},
#  27: {'roberta_neg': 0.024634356,
#   'roberta_neu': 0.08222512,
#   'roberta_pos': 0.8931405,
#   'Review': "Game is a blast whether you liked HP or not. Choice is an illusion as all outcomes are predetermined and the story isn't spectacular but the other aspects of the game more than make up for it. Solid 9/10"},
#  28: {'roberta_neg': 0.09611814,
#   'roberta_neu': 0.6751116,
#   'roberta_pos': 0.22877029,
#   'Review': 'Game of the decade'},
#  29: {'roberta_neg': 0.002679369,
#   'roberta_neu': 0.02206575,
#   'roberta_pos': 0.9752549,
#   'Review': 'Got to borrow the game, 100% lived up to the hype I had for it! Would recommend if you have the money and enjoy a good harry potter experience'},
#  31: {'roberta_neg': 0.002409526,
#   'roberta_neu': 0.0055268225,
#   'roberta_pos': 0.9920636,
#   'Review': 'I am in love with this game! There is so much to see, do and explore! The graphics are amazing even though there were some glitches in Hogsmeade but they seem to have been resolved. Amazing game over all so far.'},
#  32: {'roberta_neg': 0.0070576747,
#   'roberta_neu': 0.030360429,
#   'roberta_pos': 0.96258193,
#   'Review': "Most fun i've had in a game for years - and I'm not even a Potter fan."},
#  33: {'roberta_neg': 0.012310649,
#   'roberta_neu': 0.12469973,
#   'roberta_pos': 0.86298966,
#   'Review': 'no complaints. This is how you make a Harry Potter game!'},
#  34: {'roberta_neg': 0.29587927,
#   'roberta_neu': 0.25760067,
#   'roberta_pos': 0.44652006,
#   'Review': 'fucking amazing'},
#  35: {'roberta_neg': 0.0060983333,
#   'roberta_neu': 0.025180599,
#   'roberta_pos': 0.96872103,
#   'Review': 'Loved it'},
#  36: {'roberta_neg': 0.0033484008,
#   'roberta_neu': 0.03103669,
#   'roberta_pos': 0.965615,
#   'Review': 'Amazing "open" magic world, the main story is a little shorter than expected. They can be a lots of other new features, but it is a must for any Wizarding World fan and for the non-fan too, it a nice and different game.'},
#  37: {'roberta_neg': 0.8412268,
#   'roberta_neu': 0.12634653,
#   'roberta_pos': 0.032426573,
#   'Review': 'Great so far minus combat. This is dogshit'},
#  38: {'roberta_neg': 0.007765364,
#   'roberta_neu': 0.07029198,
#   'roberta_pos': 0.92194265,
#   'Review': 'Amazing game'},
#  39: {'roberta_neg': 0.0053856326,
#   'roberta_neu': 0.028242268,
#   'roberta_pos': 0.9663721,
#   'Review': 'best game ever'},
#  40: {'roberta_neg': 0.9532556,
#   'roberta_neu': 0.043035317,
#   'roberta_pos': 0.003709107,
#   'Review': 'Tedious, slow, presumptuous, patronising and dull.'},
#  41: {'roberta_neg': 0.0023201087,
#   'roberta_neu': 0.014971471,
#   'roberta_pos': 0.9827084,
#   'Review': 'Im only about an hour into the game but it is a blast and i highly recommend this to anyone who has watch or is into harry potter and to those who may not be into it.'},
#  42: {'roberta_neg': 0.05412309,
#   'roberta_neu': 0.48970696,
#   'roberta_pos': 0.4561699,
#   'Review': 'the game we have wanted for years'},
#  43: {'roberta_neg': 0.005379803,
#   'roberta_neu': 0.042046584,
#   'roberta_pos': 0.9525736,
#   'Review': 'Great game !'},
#  44: {'roberta_neg': 0.0022985802,
#   'roberta_neu': 0.028204113,
#   'roberta_pos': 0.96949726,
#   'Review': 'Very Good so far'},
#  45: {'roberta_neg': 0.003295585,
#   'roberta_neu': 0.06669015,
#   'roberta_pos': 0.9300143,
#   'Review': 'Living out all my childhood dreams!'},
#  46: {'roberta_neg': 0.0074301935,
#   'roberta_neu': 0.17136541,
#   'roberta_pos': 0.8212044,
#   'Review': "long but good (that's what she said)"},
#  47: {'roberta_neg': 0.024345115,
#   'roberta_neu': 0.19565572,
#   'roberta_pos': 0.7799992,
#   'Review': 'SOOO GOOOOOOD'},
#  48: {'roberta_neg': 0.14218792,
#   'roberta_neu': 0.78097695,
#   'roberta_pos': 0.07683512,
#   'Review': 'suraj chanda makkhan khalo , is gye gujre ka rang badal dalo'},
#  49: {'roberta_neg': 0.009389,
#   'roberta_neu': 0.083680086,
#   'roberta_pos': 0.906931,
#   'Review': 'Amazing!'},
#  50: {'roberta_neg': 0.0014254155,
#   'roberta_neu': 0.010639194,
#   'roberta_pos': 0.9879354,
#   'Review': 'This game is amazing, from the gameplay, cut scenes, fighting systems, graphics to how they are so inclusive and even add in LGBTQ characters.'},
#  51: {'roberta_neg': 0.05207653,
#   'roberta_neu': 0.6420737,
#   'roberta_pos': 0.3058498,
#   'Review': 'i need the new dlc'},
#  52: {'roberta_neg': 0.0023827516,
#   'roberta_neu': 0.019446295,
#   'roberta_pos': 0.97817093,
#   'Review': 'very good game i can pet cats and stuff'},
#  53: {'roberta_neg': 0.0025464373,
#   'roberta_neu': 0.039771676,
#   'roberta_pos': 0.95768195,
#   'Review': 'best game this Year yet'},
#  54: {'roberta_neg': 0.9581548,
#   'roberta_neu': 0.037233274,
#   'roberta_pos': 0.004611862,
#   'Review': "I am the most evil Hufflepuff known to man I am worse than Voldemort even. I'm so silly for using Avada Kedavra!"},
#  55: {'roberta_neg': 0.4034882,
#   'roberta_neu': 0.33685684,
#   'roberta_pos': 0.259655,
#   'Review': 'Gameplay is super fun and story is interesting enough to keep going. Very "light" though, nothing to deep, really predictable.No morality system is kind of strange though..using dark arts should be punished somehow. This destroys the immersion for me.'},
#  56: {'roberta_neg': 0.013122776,
#   'roberta_neu': 0.17258102,
#   'roberta_pos': 0.81429625,
#   'Review': 'This game makes you really feel like a wizard, it has a little something for everyone, too much water 5/7.'},
#  57: {'roberta_neg': 0.008486067,
#   'roberta_neu': 0.064623326,
#   'roberta_pos': 0.92689055,
#   'Review': 'good game'},
#  58: {'roberta_neg': 0.02821574,
#   'roberta_neu': 0.0667583,
#   'roberta_pos': 0.90502596,
#   'Review': 'Absolutely fantastic game....Huge open world tons to do great story line.....Has a few bugs that need to be fixed like optimization issues....but overall great game.....'},
#  59: {'roberta_neg': 0.08660584,
#   'roberta_neu': 0.6966731,
#   'roberta_pos': 0.21672106,
#   'Review': 'AVADA KEDAVRA!'},
#  60: {'roberta_neg': 0.0033275152,
#   'roberta_neu': 0.034622934,
#   'roberta_pos': 0.9620495,
#   'Review': '50 hours in, and its amazing.'},
#  61: {'roberta_neg': 0.0016982201,
#   'roberta_neu': 0.015155745,
#   'roberta_pos': 0.983146,
#   'Review': 'Have really enjoyed my time as a wizard'},
#  62: {'roberta_neg': 0.01582656,
#   'roberta_neu': 0.09379009,
#   'roberta_pos': 0.89038336,
#   'Review': 'Game is fun, has performance issues but outside of that the game is pretty solid.'},
#  63: {'roberta_neg': 0.0073320973,
#   'roberta_neu': 0.085672006,
#   'roberta_pos': 0.9069959,
#   'Review': 'if you want the same vibe as the original trilogy on the pc this is the game for you. also it runs better then i expected on my pc.'},
#  64: {'roberta_neg': 0.013771445,
#   'roberta_neu': 0.14726773,
#   'roberta_pos': 0.8389608,
#   'Review': "games's awsome buy it"},
#  65: {'roberta_neg': 0.14648329,
#   'roberta_neu': 0.18013649,
#   'roberta_pos': 0.6733803,
#   'Review': 'Fantastic game! 10/10 would recommend for any potter fan out there. Ignore all the bs hate from idiots.'},
#  66: {'roberta_neg': 0.0023935963,
#   'roberta_neu': 0.008202008,
#   'roberta_pos': 0.98940444,
#   'Review': "I love this game. I'm not much of a fighter, so I play Easy mode, but it is so much to explore. The Hogwarts castle is magnificent and there are so many puzzles and things to find. And the magic is great."},
#  67: {'roberta_neg': 0.009530398,
#   'roberta_neu': 0.04089766,
#   'roberta_pos': 0.94957197,
#   'Review': 'Brilliant. Some stuttering but not game breaking. Very enjoyable'},
#  68: {'roberta_neg': 0.013338635,
#   'roberta_neu': 0.38945836,
#   'roberta_pos': 0.59720296,
#   'Review': 'Vroom, Vroom, Skirrrttt!'},
#  69: {'roberta_neg': 0.01883585,
#   'roberta_neu': 0.1347456,
#   'roberta_pos': 0.84641856,
#   'Review': 'Just a seriously well made game.'},
#  70: {'roberta_neg': 0.0014754639,
#   'roberta_neu': 0.0123171145,
#   'roberta_pos': 0.98620737,
#   'Review': "It is everything I've ever wanted in a wizarding world game!!!! I hope they come out with expansions!!!"},
#  71: {'roberta_neg': 0.002338251,
#   'roberta_neu': 0.034797914,
#   'roberta_pos': 0.9628638,
#   'Review': 'Cool storyline and great paintings'},
#  72: {'roberta_neg': 0.0034203655,
#   'roberta_neu': 0.023940494,
#   'roberta_pos': 0.97263914,
#   'Review': 'Great game!'},
#  73: {'roberta_neg': 0.1677557,
#   'roberta_neu': 0.7769792,
#   'roberta_pos': 0.05526504,
#   'Review': 'Professor Garlick. Need I say more?'},
#  74: {'roberta_neg': 0.819693,
#   'roberta_neu': 0.15854831,
#   'roberta_pos': 0.021758668,
#   'Review': "please fix stuttering and FPS drop my pc system have above requirement but can't play this game with 60 fps"},
#  75: {'roberta_neg': 0.20285198,
#   'roberta_neu': 0.72772455,
#   'roberta_pos': 0.069423534,
#   'Review': "It's like Assassin's Creed with wizards"},
#  76: {'roberta_neg': 0.0015745125,
#   'roberta_neu': 0.016240561,
#   'roberta_pos': 0.98218495,
#   'Review': 'yeah, its pretty cool game'},
#  77: {'roberta_neg': 0.7215622,
#   'roberta_neu': 0.2416043,
#   'roberta_pos': 0.036833443,
#   'Review': "got in to a spiders cave and fell from a cliff, now my entire game got stuck mid air. It acts like i am with the mouse on an image, no reaction, I've hit all the buttons from my keyboard to get a move.From a to z and f1 to f12 not a single button got me unstuck.I am currently removing the game. Hoping uninstall/install will solve the issue."},
#  78: {'roberta_neg': 0.10970601,
#   'roberta_neu': 0.6356832,
#   'roberta_pos': 0.25461084,
#   'Review': 'Forget petting.. you can levitate and shoot every Cat in this game'},
#  79: {'roberta_neg': 0.31647664,
#   'roberta_neu': 0.5971856,
#   'roberta_pos': 0.08633772,
#   'Review': 'just play it and stop reading comments'},
#  80: {'roberta_neg': 0.6653383,
#   'roberta_neu': 0.27843755,
#   'roberta_pos': 0.056224216,
#   'Review': "all it does is crash.i try optimizing my settings, crashes.i try reinstalling, crashes.i try verifying files, crashes.turn off ray tracing, crashes.turn off other options, crashes.reduce from ultra to low, crashes.my recommended settings are ultra everything and everything on. my pc can play it, but the game just crashes.i play 2 minutes, crashes.i play 10 minutes, crashes.crashes, crashes, crashes.will update with recommend if the game gets fixed so i'm not crashing every time i try to play."},
#  81: {'roberta_neg': 0.0020223153,
#   'roberta_neu': 0.01944209,
#   'roberta_pos': 0.9785356,
#   'Review': 'very fun game with a beautiful interactive world with lots of secrets!'},
#  82: {'roberta_neg': 0.006336458,
#   'roberta_neu': 0.08863504,
#   'roberta_pos': 0.9050285,
#   'Review': 'good soup'},
#  83: {'roberta_neg': 0.0024844615,
#   'roberta_neu': 0.011344631,
#   'roberta_pos': 0.9861709,
#   'Review': 'The game is amazing'},
#  84: {'roberta_neg': 0.5484515,
#   'roberta_neu': 0.4190597,
#   'roberta_pos': 0.03248888,
#   'Review': 'Latest update added lag to the game'},
#  85: {'roberta_neg': 0.8713762,
#   'roberta_neu': 0.1165179,
#   'roberta_pos': 0.012105916,
#   'Review': 'Awful stuttering, borderline unplayable until fixed. Will remove review when this eventually happensRTX 3060, Ryzan 7 5700G, 16GB DDR4 ram'},
#  86: {'roberta_neg': 0.015933635,
#   'roberta_neu': 0.24843332,
#   'roberta_pos': 0.7356331,
#   'Review': 'Deek thinks you should be proud of all the potions you’ve brewed!'},
#  87: {'roberta_neg': 0.47525024,
#   'roberta_neu': 0.39894697,
#   'roberta_pos': 0.1258028,
#   'Review': 'you aint gotta read or watch nothin to enjoy this game'},
#  88: {'roberta_neg': 0.002702673,
#   'roberta_neu': 0.016304933,
#   'roberta_pos': 0.9809924,
#   'Review': 'amazing story amazing game 5/5 definetly game of the year'},
#  89: {'roberta_neg': 0.0034353517,
#   'roberta_neu': 0.023698919,
#   'roberta_pos': 0.97286576,
#   'Review': 'Super fun game'},
#  90: {'roberta_neg': 0.0025306193,
#   'roberta_neu': 0.049622692,
#   'roberta_pos': 0.94784665,
#   'Review': 'best game since the witcher 3'},
#  91: {'roberta_neg': 0.0034630264,
#   'roberta_neu': 0.02528353,
#   'roberta_pos': 0.9712534,
#   'Review': 'good game!'},
#  92: {'roberta_neg': 0.116742335,
#   'roberta_neu': 0.28371805,
#   'roberta_pos': 0.5995397,
#   'Review': 'A very pretty game but shallow in execution'},
#  93: {'roberta_neg': 0.008418264,
#   'roberta_neu': 0.06241453,
#   'roberta_pos': 0.9291672,
#   'Review': 'its great'},
#  94: {'roberta_neg': 0.59400964,
#   'roberta_neu': 0.2663981,
#   'roberta_pos': 0.13959222,
#   'Review': "Performance is horrible, optimization was clearly not on the minds of the developers, a shame. Everything about this game is wonderful but just given the performance I cannot in good faith recommend this product. Refunded. Buy it on a console if you have the next-gen hardware, it's gonna save you a ton of headaches, mods aren't worth it here."},
#  95: {'roberta_neg': 0.031668182,
#   'roberta_neu': 0.19795273,
#   'roberta_pos': 0.7703791,
#   'Review': 'Awesome for someone with ADD'},
#  96: {'roberta_neg': 0.00899986,
#   'roberta_neu': 0.096495576,
#   'roberta_pos': 0.89450455,
#   'Review': 'Good Game'},
#  97: {'roberta_neg': 0.014027719,
#   'roberta_neu': 0.10808051,
#   'roberta_pos': 0.8778918,
#   'Review': "It's like dream come true.NOT!! a very big fan of Harry Potter but have played older games and have always wondered how it would fell to have an open world game of it.It's an entirely different experience it's open world like other games but MAGICAL!!"},
#  98: {'roberta_neg': 0.0027554221,
#   'roberta_neu': 0.015337413,
#   'roberta_pos': 0.9819072,
#   'Review': 'Very good game!!'},
#  99: {'roberta_neg': 0.0029446601,
#   'roberta_neu': 0.049478807,
#   'roberta_pos': 0.9475765,
#   'Review': 'Good contender for GOTY. Very addictive, and nastalgic. Worth the buy'}}

# %%
result_df = pd.DataFrame(roberta_result)

# %%
result_df = result_df.T
result_df.head()
# Out:
#   roberta_neg roberta_neu roberta_pos  \
# 0    0.002688    0.024788    0.972525
# 1    0.002785    0.029467    0.967748
# 2    0.116993    0.573539    0.309468
# 3    0.008601    0.033362    0.958037
# 4     0.00922     0.06757     0.92321
#
#                                               Review
# 0                                      Greattt Game!
# 1  9/10Fantastic experience. A true Wizarding Wor...
# 2                                           worth it
# 3  I've been waiting 84 YEARSSSSSSSS.The game is ...
# 4       very fun game (it is not transphobic at all)

# %%
combined_dataframe = pd.merge(result_df, df, on='Review', how='inner')

# %%
combined_dataframe.head()
# Out:
#   roberta_neg roberta_neu roberta_pos  \
# 0    0.002688    0.024788    0.972525
# 1    0.002785    0.029467    0.967748
# 2    0.116993    0.573539    0.309468
# 3    0.008601    0.033362    0.958037
# 4     0.00922     0.06757     0.92321
#
#                                               Review  Playtime  Feedback
# 0                                      Greattt Game!        16  Positive
# 1  9/10Fantastic experience. A true Wizarding Wor...        26  Positive
# 2                                           worth it        29  Positive
# 3  I've been waiting 84 YEARSSSSSSSS.The game is ...        24  Positive
# 4       very fun game (it is not transphobic at all)         7  Positive
